# %% [markdown]
# # PISA Data
# ## by Richard Guitter
#
# ## Preliminary Wrangling
#
# The Programme for International Student Assessment (PISA) is a triennial international survey which aims to evaluate education systems worldwide by testing the skills and knowledge of 15-year-old students who are nearing the end of their compulsory education. PISA assesses how well they can apply what they learn in school to real-life situations.
#
# This dataset contains the result of the survey for 2012.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

pd.set_option('display.max_columns', 636)

# %%
pisa = pd.read_csv('pisa2012.csv', encoding='latin-1',
       index_col=0,
       dtype={15: str, 16: str, 17: str, 21: str, 22: str, 23: str, 24: str, 25: str, 26: str, 37: str,
           45: str, 65: str, 123: str, 156: str, 157: str, 158: str, 159: str, 160: str, 161: str,
           162: str, 163: str, 164: str, 165: str, 166: str, 167: str, 168: str, 169: str, 170: str,
           171: str, 284: str, 285: str, 286: str, 287: str, 288: str, 289: str, 290: str, 291: str,
           292: str, 293: str, 294: str, 295: str, 296: str, 297: str, 298: str, 299: str, 300: str,
           301: str, 302: str, 303: str, 307: str, 308: str, 309: str, 310: str, 311: str, 312: str,
           313: str, 314: str, 315: str, 316: str, 317: str, 318: str, 319: str, 320: str, 321: str,
           322: str, 323: str, 324: str, 325: str, 326: str, 327: str, 328: str, 329: str, 330: str,
           331: str, 332: str, 333: str, 334: str, 335: str, 336: str, 337: str, 338: str, 339: str,
           340: str, 341: str, 342: str, 343: str, 344: str, 345: str, 346: str, 347: str, 348: str,
           349: str, 350: str, 351: str, 352: str, 353: str, 354: str, 355: str, 356: str, 357: str,
           376: str, 377: str, 378: str, 379: str, 380: str, 381: str, 382: str, 383: str, 384: str,
           385: str, 386: str, 387: str, 388: str, 389: str, 390: str, 391: str, 392: str, 393: str,
           394: str, 395: str, 396: str, 397: str, 398: str, 399: str, 400: str, 401: str, 402: str,
           403: str, 475: str, 30: str, 31: str, 36: str, 155: str}
)

# %%
pisa.head()
# Out:
#        CNT  SUBNATIO  STRATUM      OECD       NC  SCHOOLID  STIDSTD  ST01Q01  \
# 1  Albania     80000  ALB0006  Non-OECD  Albania         1        1       10
# 2  Albania     80000  ALB0006  Non-OECD  Albania         1        2       10
# 3  Albania     80000  ALB0006  Non-OECD  Albania         1        3        9
# 4  Albania     80000  ALB0006  Non-OECD  Albania         1        4        9
# 5  Albania     80000  ALB0006  Non-OECD  Albania         1        5        9
#
#    ST02Q01  ST03Q01  ST03Q02 ST04Q01                      ST05Q01  ST06Q01  \
# 1      1.0        2     1996  Female                         No        6.0
# 2      1.0        2     1996  Female  Yes, for more than one year      7.0
# 3      1.0        9     1996  Female  Yes, for more than one year      6.0
# 4      1.0        8     1996  Female  Yes, for more than one year      6.0
# 5      1.0       10     1996  Female  Yes, for more than one year      6.0
#
#      ST07Q01    ST07Q02    ST07Q03             ST08Q01 ST09Q01  ST115Q01  \
# 1  No, never  No, never  No, never              None    None         1.0
# 2  No, never  No, never  No, never  One or two times    None         1.0
# 3  No, never  No, never  No, never              None    None         1.0
# 4  No, never  No, never  No, never              None    None         1.0
# 5  No, never  No, never  No, never  One or two times    None         2.0
#
#   ST11Q01 ST11Q02 ST11Q03 ST11Q04 ST11Q05 ST11Q06  \
# 1     Yes     Yes     Yes     Yes     NaN     NaN
# 2     Yes     Yes     NaN     Yes     NaN     NaN
# 3     Yes     Yes      No     Yes      No      No
# 4     Yes     Yes      No     Yes      No      No
# 5     Yes     Yes     Yes     NaN     NaN     NaN
#
#                                  ST13Q01 ST14Q01 ST14Q02 ST14Q03 ST14Q04  \
# 1                      <ISCED level 3A>       No      No      No      No
# 2                      <ISCED level 3A>      Yes     Yes      No      No
# 3                  <ISCED level 3B, 3C>      Yes     Yes     Yes      No
# 4                  <ISCED level 3B, 3C>       No      No      No      No
# 5  She did not complete <ISCED level 1>       No      No      No      No
#
#                               ST15Q01                ST17Q01 ST18Q01 ST18Q02  \
# 1  Other (e.g. home duties, retired)       <ISCED level 3A>      NaN     NaN
# 2        Working full-time <for pay>       <ISCED level 3A>       No      No
# 3        Working full-time <for pay>       <ISCED level 3A>      Yes      No
# 4        Working full-time <for pay>       <ISCED level 3A>      Yes     Yes
# 5         Working part-time <for pay>  <ISCED level 3B, 3C>       No      No
#
#   ST18Q03 ST18Q04                       ST19Q01          ST20Q01  \
# 1     NaN     NaN   Working part-time <for pay>  Country of test
# 2      No      No  Working full-time <for pay>   Country of test
# 3     Yes     Yes  Working full-time <for pay>   Country of test
# 4      No      No  Working full-time <for pay>   Country of test
# 5      No     Yes   Working part-time <for pay>  Country of test
#
#            ST20Q02          ST20Q03  ST21Q01               ST25Q01 ST26Q01  \
# 1  Country of test  Country of test      NaN  Language of the test     Yes
# 2  Country of test  Country of test      NaN  Language of the test     Yes
# 3  Country of test  Country of test      NaN  Language of the test     Yes
# 4  Country of test  Country of test      NaN  Language of the test     Yes
# 5  Country of test  Country of test      NaN  Language of the test     Yes
#
#   ST26Q02 ST26Q03 ST26Q04 ST26Q05 ST26Q06 ST26Q07 ST26Q08 ST26Q09 ST26Q10  \
# 1      No     Yes      No      No      No      No     Yes      No     Yes
# 2     Yes     Yes     Yes     Yes     Yes     Yes     Yes     Yes     Yes
# 3     Yes     Yes     Yes      No     Yes     Yes     Yes     Yes     Yes
# 4     Yes     Yes     Yes     Yes     Yes     Yes     Yes     Yes     Yes
# 5     Yes      No     Yes     Yes     Yes     Yes     Yes     Yes     Yes
#
#   ST26Q11 ST26Q12 ST26Q13 ST26Q14  ST26Q15  ST26Q16  ST26Q17        ST27Q01  \
# 1      No     Yes      No     Yes     8002     8001     8002            Two
# 2     Yes     Yes     Yes     Yes     8001     8001     8002  Three or more
# 3      No     Yes      No     Yes     8001     8001     8001  Three or more
# 4      No     Yes     Yes      No     8001     8001     8002  Three or more
# 5      No     Yes     Yes     Yes     8001     8002     8001            Two
#
#          ST27Q02        ST27Q03 ST27Q04 ST27Q05              ST28Q01  \
# 1            One           None    None    None          0-10 books
# 2  Three or more  Three or more     Two     Two       201-500 books
# 3            Two            Two     One     Two  More than 500 books
# 4            Two            One    None     One         11-25 books
# 3  Strongly disagree  Likely           Likely    Very   Likely  Very   Likely
# 4                NaN     NaN              NaN              NaN            NaN
# 5           Disagree  Likely           Likely           Likely         Likely
#
#            ST44Q07          ST44Q08         ST46Q01         ST46Q02  \
# 1           Likely    Very   Likely           Agree           Agree
# 2  Slightly likely           Likely           Agree           Agree
# 3    Very   Likely  Slightly likely  Strongly agree  Strongly agree
# 4              NaN              NaN             NaN             NaN
# 5  Slightly likely    Very   Likely  Strongly agree  Strongly agree
#
#           ST46Q03         ST46Q04         ST46Q05 ST46Q06         ST46Q07  \
# 1           Agree           Agree           Agree   Agree           Agree
# 2  Strongly agree  Strongly agree  Strongly agree   Agree           Agree
# 3  Strongly agree  Strongly agree  Strongly agree   Agree  Strongly agree
# 4             NaN             NaN             NaN     NaN             NaN
# 5           Agree  Strongly agree  Strongly agree   Agree  Strongly agree
#
#           ST46Q08         ST46Q09                             ST48Q01  \
# 1           Agree           Agree  Courses after school Test Language
# 2        Disagree           Agree           Courses after school Math
# 3  Strongly agree  Strongly agree           Courses after school Math
# 4             NaN             NaN                                 NaN
# 5  Strongly agree  Strongly agree  Courses after school Test Language
#
#                     ST48Q02                     ST48Q03  \
# 1  Major in college Science  Study harder Test Language
# 2  Major in college Science           Study harder Math
# 3  Major in college Science           Study harder Math
# 4                       NaN                         NaN
# 5     Major in college Math           Study harder Math
#
#                    ST48Q04                    ST48Q05  \
# 1  Maximum classes Science     Pursuing a career Math
# 2  Maximum classes Science  Pursuing a career Science
# 3  Maximum classes Science  Pursuing a career Science
# 4                      NaN                        NaN
# 5     Maximum classes Math     Pursuing a career Math
#
#                    ST49Q01                  ST49Q02                  ST49Q03  \
# 1                    Often                Sometimes                Sometimes
# 2                Sometimes                    Often  Always or almost always
# 3                Sometimes  Always or almost always                Sometimes
# 4                      NaN                      NaN                      NaN
# 5  Always or almost always  Always or almost always                    Often
#
#            ST49Q04                  ST49Q05          ST49Q06          ST49Q07  \
# 1        Sometimes                Sometimes  Never or rarely  Never or rarely
# 2        Sometimes  Always or almost always  Never or rarely  Never or rarely
# 3  Never or rarely  Always or almost always  Never or rarely  Never or rarely
# 4              NaN                      NaN              NaN              NaN
# 5            Often                Sometimes              NaN        Sometimes
#
#            ST49Q09            ST53Q01                ST53Q02         ST53Q03  \
# 1  Never or rarely                NaN                    NaN             NaN
# 2            Often  relating to known  Improve understanding     in my sleep
# 3  Never or rarely     Most important  Improve understanding  learning goals
# 4              NaN  relating to known               new ways  learning goals
# 5        Sometimes                NaN                    NaN             NaN
#
#             ST53Q04                                            ST55Q01  \
# 1               NaN                                                NaN
# 2   Repeat examples  I do not attend <out-of-school time lessons> i...
# 3  more information                           Less than 2 hours a week
# 4  more information  I do not attend <out-of-school time lessons> i...
# 5               NaN                                                NaN
#
#                                              ST55Q02  \
# 1                                                NaN
# 2             2 or more but less than 4 hours a week
# 3             2 or more but less than 4 hours a week
# 4  I do not attend <out-of-school time lessons> i...
# 5                                                NaN
#
#                                   ST55Q03  \
# 1                                     NaN
# 2  2 or more but less than 4 hours a week
# 3  4 or more but less than 6 hours a week
# 4                Less than 2 hours a week
# 5                                     NaN
#
#                                              ST55Q04  ST57Q01  ST57Q02  \
# 1                                                NaN      NaN      NaN
# 2                           Less than 2 hours a week      NaN      NaN
# 3  I do not attend <out-of-school time lessons> i...      NaN      6.0
# 4  I do not attend <out-of-school time lessons> i...     10.0      2.0
# 5                                                NaN      NaN      NaN
#
#    ST57Q03  ST57Q04  ST57Q05  ST57Q06     ST61Q01    ST61Q02     ST61Q03  \
# 1      NaN      NaN      NaN      NaN         NaN        NaN         NaN
# 2      6.0      0.0      0.0      2.0     Rarely     Rarely   Frequently
# 3      6.0      7.0      2.0      3.0  Frequently  Sometimes  Frequently
# 4      2.0      0.0      0.0      3.0   Sometimes  Sometimes   Sometimes
# 5      NaN      NaN      NaN      NaN         NaN        NaN         NaN
#
#      ST61Q04     ST61Q05    ST61Q06     ST61Q07    ST61Q08     ST61Q09  \
# 1        NaN         NaN        NaN         NaN        NaN         NaN
# 2  Sometimes  Frequently  Sometimes  Frequently     Never   Frequently
# 3    Rarely   Frequently    Rarely   Frequently  Sometimes  Frequently
# 4  Sometimes  Frequently  Sometimes  Frequently    Rarely   Frequently
# 5        NaN         NaN        NaN         NaN        NaN         NaN
#
#                                  ST62Q01  \
# 1                                    NaN
# 2  Know it well,  understand the concept
# 3                      Never heard of it
# 4                      Heard of it often
# 5                                    NaN
#
#                                  ST62Q02                    ST62Q03  \
# 1                                    NaN                        NaN
# 2  Know it well,  understand the concept  Heard of it once or twice
# 3  Know it well,  understand the concept  Heard of it once or twice
# 4                      Heard of it often          Heard of it often
# 5                                    NaN                        NaN
#
#                                  ST62Q04  \
# 1                                    NaN
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4  Know it well,  understand the concept
# 5                                    NaN
#
#                                  ST62Q06  \
# 1                                    NaN
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4                Heard of it a few times
# 5                                    NaN
#
#                                  ST62Q07                    ST62Q08  \
# 1                                    NaN                        NaN
# 2  Know it well,  understand the concept          Never heard of it
# 3  Know it well,  understand the concept  Heard of it once or twice
# 4  Know it well,  understand the concept          Never heard of it
# 5                                    NaN                        NaN
#
#                                  ST62Q09  \
# 1                                    NaN
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4  Know it well,  understand the concept
# 5                                    NaN
#
#                                  ST62Q10                    ST62Q11  \
# 1                                    NaN                        NaN
# 2  Know it well,  understand the concept          Never heard of it
# 3  Know it well,  understand the concept  Heard of it once or twice
# 4  Know it well,  understand the concept          Never heard of it
# 5                                    NaN                        NaN
#
#                                  ST62Q12  \
# 1                                    NaN
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4  Know it well,  understand the concept
# 5                                    NaN
#
#                                  ST62Q13  \
# 1                                    NaN
# 2              Heard of it once or twice
# 3  Know it well,  understand the concept
# 4                      Never heard of it
# 5                                    NaN
#
#                                  ST62Q15  \
# 1                                    NaN
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4  Know it well,  understand the concept
# 5                                    NaN
#
#                                  ST62Q16  \
# 1                                    NaN
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4  Know it well,  understand the concept
# 5                                    NaN
#
#                                  ST62Q17  \
# 1                                    NaN
# 2                      Never heard of it
# 3  Know it well,  understand the concept
# 4                      Heard of it often
# 5                                    NaN
#
#                                  ST62Q19  ST69Q01  ST69Q02  ST69Q03  ST70Q01  \
# 1                                    NaN      NaN      NaN      NaN      NaN
# 2                      Heard of it often     45.0     45.0     45.0      7.0
# 3  Know it well,  understand the concept     60.0      NaN      NaN      5.0
# 4                      Heard of it often     45.0     45.0     45.0      3.0
# 5                                    NaN      NaN      NaN      NaN      NaN
#
#    ST70Q02  ST70Q03  ST71Q01  ST72Q01     ST73Q01     ST73Q02     ST74Q01  \
# 1      NaN      NaN      NaN      NaN         NaN         NaN         NaN
# 2      6.0      2.0      NaN     30.0  Frequently   Sometimes  Frequently
# 3      4.0      2.0     24.0     30.0  Frequently  Frequently  Frequently
# 4      3.0      2.0      NaN     28.0  Frequently   Sometimes  Frequently
# 5      NaN      NaN      NaN      NaN         NaN         NaN         NaN
#
#       ST74Q02     ST75Q01     ST75Q02    ST76Q01    ST76Q02       ST77Q01  \
# 1         NaN         NaN         NaN        NaN        NaN  Every Lesson
# 2  Frequently   Sometimes   Sometimes  Sometimes  Sometimes           NaN
# 3  Frequently  Frequently  Frequently    Rarely     Rarely            NaN
# 4     Rarely   Frequently  Frequently  Sometimes  Sometimes  Every Lesson
# 5         NaN         NaN         NaN        NaN        NaN  Every Lesson
#
#         ST77Q02       ST77Q04       ST77Q05       ST77Q06  \
# 1  Every Lesson  Every Lesson  Every Lesson  Every Lesson
# 2           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN
# 4  Every Lesson  Every Lesson  Every Lesson  Every Lesson
# 5  Most Lessons  Every Lesson  Most Lessons  Some Lessons
#
#                 ST79Q01       ST79Q02               ST79Q03       ST79Q04  \
# 1  Never or Hardly Ever  Most Lessons  Never or Hardly Ever  Every Lesson
# 2                   NaN           NaN                   NaN           NaN
# 3                   NaN           NaN                   NaN           NaN
# 4                   NaN  Every Lesson          Every Lesson  Every Lesson
# 5          Some Lessons  Some Lessons          Most Lessons  Some Lessons
#
#         ST79Q05       ST79Q06       ST79Q07       ST79Q08  \
# 1  Most Lessons  Every Lesson  Every Lesson  Every Lesson
# 2           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN
# 4  Every Lesson  Every Lesson  Every Lesson  Every Lesson
# 5  Most Lessons  Every Lesson  Most Lessons  Every Lesson
#
#                 ST79Q10               ST79Q11       ST79Q12       ST79Q15  \
# 1  Never or Hardly Ever          Most Lessons  Every Lesson  Every Lesson
# 2                   NaN                   NaN           NaN           NaN
# 3                   NaN                   NaN           NaN           NaN
# 4          Every Lesson  Never or Hardly Ever  Most Lessons  Every Lesson
# 5          Some Lessons          Most Lessons  Most Lessons  Every Lesson
#
#         ST79Q17                  ST80Q01    ST80Q04          ST80Q05  \
# 1  Every Lesson  Always or almost always  Sometimes  Never or rarely
# 2           NaN                      NaN        NaN              NaN
# 3           NaN                      NaN        NaN              NaN
# 4  Every Lesson  Always or almost always        NaN              NaN
# 5  Most Lessons  Always or almost always      Often        Sometimes
#
#                    ST80Q06                  ST80Q07                  ST80Q08  \
# 1  Always or almost always  Always or almost always  Always or almost always
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
# 5                    Often                    Often                    Often
#
#                    ST80Q09 ST80Q10          ST80Q11               ST81Q01  \
# 1  Always or almost always   Often            Often  Never or Hardly Ever
# 2                      NaN     NaN              NaN                   NaN
# 3                      NaN     NaN              NaN                   NaN
# 4                      NaN     NaN  Never or rarely  Never or Hardly Ever
# 5  Always or almost always   Often            Often          Some Lessons
#
#                 ST81Q02               ST81Q03               ST81Q04  \
# 1  Never or Hardly Ever  Never or Hardly Ever  Never or Hardly Ever
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4  Never or Hardly Ever  Never or Hardly Ever  Never or Hardly Ever
# 5          Some Lessons                   NaN          Most Lessons
#
#                 ST81Q05            ST82Q01            ST82Q02  \
# 1  Never or Hardly Ever  Strongly disagree  Strongly disagree
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# 5  Never or Hardly Ever  Strongly disagree           Disagree
#
#              ST82Q03            ST83Q01         ST83Q02         ST83Q03  \
# 1  Strongly disagree  Strongly disagree           Agree           Agree
# 2                NaN                NaN             NaN             NaN
# 3                NaN                NaN             NaN             NaN
# 4     Strongly agree     Strongly agree  Strongly agree  Strongly agree
# 5     Strongly agree     Strongly agree           Agree  Strongly agree
#
#   ST83Q04         ST84Q01         ST84Q02   ST84Q03 ST85Q01  \
# 1   Agree  Strongly agree  Strongly agree  Disagree   Agree
# 2     NaN             NaN             NaN       NaN     NaN
# 3     NaN             NaN             NaN       NaN     NaN
# 4     NaN             NaN             NaN       NaN     NaN
# 5   Agree        Disagree  Strongly agree  Disagree   Agree
#
#              ST85Q02         ST85Q03 ST85Q04 ST86Q01            ST86Q02  \
# 1  Strongly disagree        Disagree   Agree   Agree  Strongly disagree
# 2                NaN             NaN     NaN     NaN                NaN
# 3                NaN             NaN     NaN     NaN                NaN
# 4                NaN             NaN     NaN     NaN                NaN
# 5              Agree  Strongly agree   Agree   Agree              Agree
#
#   ST86Q03 ST86Q04   ST86Q05            ST87Q01         ST87Q02  \
# 1   Agree   Agree  Disagree              Agree           Agree
# 2     NaN     NaN       NaN                NaN             NaN
# 3     NaN     NaN       NaN                NaN             NaN
# 4     NaN     NaN       NaN                NaN             NaN
# 5   Agree   Agree     Agree  Strongly disagree  Strongly agree
#
#              ST87Q03            ST87Q04         ST87Q05            ST87Q06  \
# 1  Strongly disagree     Strongly agree  Strongly agree  Strongly disagree
# 2                NaN                NaN             NaN                NaN
# 3                NaN                NaN             NaN                NaN
# 4                NaN                NaN             NaN                NaN
# 5     Strongly agree  Strongly disagree  Strongly agree  Strongly disagree
#
#           ST87Q07            ST87Q08         ST87Q09   ST88Q01  \
# 1           Agree  Strongly disagree           Agree     Agree
# 2             NaN                NaN             NaN       NaN
# 3             NaN                NaN             NaN       NaN
# 4             NaN                NaN             NaN       NaN
# 5  Strongly agree     Strongly agree  Strongly agree  Disagree
#
#              ST88Q02            ST88Q03            ST88Q04         ST89Q02  \
# 1     Strongly agree  Strongly disagree  Strongly disagree           Agree
# 2                NaN                NaN                NaN             NaN
# 3                NaN                NaN                NaN             NaN
# 4                NaN                NaN                NaN             NaN
# 5  Strongly disagree     Strongly agree     Strongly agree  Strongly agree
#
#           ST89Q03         ST89Q04         ST89Q05         ST91Q01  \
# 1  Strongly agree  Strongly agree  Strongly agree  Strongly agree
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
# 5  Strongly agree  Strongly agree  Strongly agree           Agree
#
#           ST91Q02            ST91Q03            ST91Q04         ST91Q05  \
# 1  Strongly agree     Strongly agree  Strongly disagree        Disagree
# 2             NaN                NaN                NaN             NaN
# 3             NaN                NaN                NaN             NaN
# 4             NaN                NaN                NaN             NaN
# 5  Strongly agree  Strongly disagree              Agree  Strongly agree
#
#              ST91Q06             ST93Q01             ST93Q03  \
# 1  Strongly disagree   Very much like me   Very much like me
# 2                NaN  Not at all like me  Not at all like me
# 3                NaN    Not much like me    Not much like me
# 4                NaN                 NaN                 NaN
# 5           Disagree                 NaN      Mostly like me
#
#              ST93Q04            ST93Q06            ST93Q07            ST94Q05  \
# 1  Very much like me   Somewhat like me  Very much like me   Somewhat like me
# 2     Mostly like me   Somewhat like me  Very much like me   Somewhat like me
# 3  Very much like me  Very much like me   Somewhat like me     Mostly like me
# 4                NaN                NaN                NaN                NaN
# 5  Very much like me  Very much like me  Very much like me  Very much like me
#
#              ST94Q06            ST94Q09            ST94Q10            ST94Q14  \
# 1     Mostly like me     Mostly like me     Mostly like me   Somewhat like me
# 2   Not much like me   Not much like me     Mostly like me   Not much like me
# 3     Mostly like me  Very much like me     Mostly like me  Very much like me
# 4                NaN                NaN                NaN                NaN
# 5  Very much like me     Mostly like me  Very much like me     Mostly like me
#
#                 ST96Q01             ST96Q02                 ST96Q03  \
# 1    definitely do this  definitely do this      definitely do this
# 2  probably not do this    probably do this    probably not do this
# 3  probably not do this  definitely do this  definitely not do this
# 4                   NaN                 NaN                     NaN
# 5    definitely do this  definitely do this      definitely do this
#
#               ST96Q05  ST101Q01  ST101Q02  ST101Q03  ST101Q05  ST104Q01  \
# 1  definitely do this       4.0       2.0       1.0       1.0       1.0
# 2    probably do this       1.0       2.0       3.0       2.0       2.0
# 3    probably do this       1.0       3.0       4.0       1.0       3.0
# 4                 NaN       NaN       NaN       NaN       NaN       NaN
# 5  definitely do this       1.0       2.0       1.0       2.0       1.0
#
#    ST104Q04  ST104Q05  ST104Q06 IC01Q01 IC01Q02 IC01Q03 IC01Q04 IC01Q05  \
# 1       2.0       1.0       1.0     NaN     NaN     NaN     NaN     NaN
# 2       3.0       1.0       1.0     NaN     NaN     NaN     NaN     NaN
# 3       4.0       1.0       1.0     NaN     NaN     NaN     NaN     NaN
# 4       NaN       NaN       NaN     NaN     NaN     NaN     NaN     NaN
# 5       2.0       1.0       1.0     NaN     NaN     NaN     NaN     NaN
#
#   IC01Q06 IC01Q07 IC01Q08 IC01Q09 IC01Q10 IC01Q11 IC02Q01 IC02Q02 IC02Q03  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC02Q04 IC02Q05 IC02Q06 IC02Q07 IC03Q01 IC04Q01  IC05Q01  IC06Q01  IC07Q01  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
# 2     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
# 3     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
# 4     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
# 5     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
#
#   IC08Q01 IC08Q02 IC08Q03 IC08Q04 IC08Q05 IC08Q06 IC08Q07 IC08Q08 IC08Q09  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC08Q11 IC09Q01 IC09Q02 IC09Q03 IC09Q04 IC09Q05 IC09Q06 IC09Q07 IC10Q01  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC10Q02 IC10Q03 IC10Q04 IC10Q05 IC10Q06 IC10Q07 IC10Q08 IC10Q09 IC11Q01  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC11Q02 IC11Q03 IC11Q04 IC11Q05 IC11Q06 IC11Q07 IC22Q01 IC22Q02 IC22Q04  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC22Q06 IC22Q07 IC22Q08 EC01Q01 EC02Q01 EC03Q01 EC03Q02 EC03Q03 EC03Q04  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   EC03Q05 EC03Q06 EC03Q07 EC03Q08 EC03Q09 EC03Q10  EC04Q01A  EC04Q01B  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
#
#    EC04Q01C  EC04Q02A  EC04Q02B  EC04Q02C  EC04Q03A  EC04Q03B  EC04Q03C  \
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    EC04Q04A  EC04Q04B  EC04Q04C  EC04Q05A  EC04Q05B  EC04Q05C  EC04Q06A  \
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    EC04Q06B  EC04Q06C EC05Q01 EC06Q01 EC07Q01 EC07Q02 EC07Q03 EC07Q04 EC07Q05  \
# 1       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   EC08Q01 EC08Q02 EC08Q03 EC08Q04 EC09Q03 EC10Q01 EC11Q02 EC11Q03 EC12Q01  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   ST22Q01 ST23Q01 ST23Q02 ST23Q03 ST23Q04 ST23Q05 ST23Q06 ST23Q07 ST23Q08  \
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   ST24Q01 ST24Q02 ST24Q03              CLCUSE1  CLCUSE301  CLCUSE302  DEFFORT  \
# 1     NaN     NaN     NaN  A Simple calculator         99         99       99
# 2     NaN     NaN     NaN  A Simple calculator         99         99       99
# 3     NaN     NaN     NaN  A Simple calculator         99         99       99
# 4     NaN     NaN     NaN                  NaN         99         99       99
# 5     NaN     NaN     NaN                  NaN         99         99       99
#
#       QUESTID     BOOKID                      EASY    AGE  GRADE  \
# 1  StQ Form B  booklet 7  Standard set of booklets  16.17    0.0
# 2  StQ Form A  booklet 9  Standard set of booklets  16.17    0.0
# 3  StQ Form A  booklet 3  Standard set of booklets  15.58   -1.0
# 4  StQ Form C  booklet 2  Standard set of booklets  15.67   -1.0
# 5  StQ Form B  booklet 4  Standard set of booklets  15.50   -1.0
#
#                                 PROGN  ANXMAT  ATSCHL  ATTLNACT  BELONG  \
# 1  Albania: Upper secondary education    0.32   -2.31    0.5206   -1.18
# 2  Albania: Upper secondary education     NaN     NaN       NaN     NaN
# 3  Albania: Lower secondary education     NaN     NaN       NaN     NaN
# 4  Albania: Lower secondary education    0.31     NaN       NaN     NaN
# 5  Albania: Lower secondary education    1.02    1.38    1.2115    2.63
#
#    BFMJ2  BMMJ1  CLSMAN   COBN_F   COBN_M   COBN_S  COGACT  CULTDIST  CULTPOS  \
# 1  76.49  79.74 -1.3771  Albania  Albania  Albania  0.6994       NaN    -0.48
# 2  15.35  23.47     NaN  Albania  Albania  Albania     NaN       NaN     1.27
# 3  22.57    NaN     NaN  Albania  Albania  Albania     NaN       NaN     1.27
# 4  14.21    NaN     NaN  Albania  Albania  Albania -0.3788       NaN     1.27
# 5  80.92    NaN -0.0784  Albania  Albania  Albania  0.5403       NaN     1.27
#
#    DISCLIMA  ENTUSE  ESCS  EXAPPLM  EXPUREM  FAILMAT  FAMCON  FAMCONC  \
# 1      1.85     NaN   NaN      NaN      NaN   0.6400     NaN      NaN
# 2       NaN     NaN   NaN  -0.0681   0.7955   0.1524  0.6387    -0.08
# 3       NaN     NaN   NaN   0.5359   0.7955   1.2219  0.8215    -0.89
# 4      1.80     NaN   NaN   0.3220   0.7955      NaN  0.7266     0.24
# 5     -0.08     NaN   NaN      NaN      NaN   0.6400     NaN      NaN
#
#    FAMSTRUC             FISCED  HEDRES  HERITCUL             HISCED  HISEI  \
# 1       2.0  ISCED 3A, ISCED 4   -1.29       NaN  ISCED 3A, ISCED 4    NaN
# 2       2.0  ISCED 3A, ISCED 4    1.12       NaN        ISCED 5A, 6    NaN
# 3       2.0        ISCED 5A, 6   -0.69       NaN        ISCED 5A, 6    NaN
# 4       2.0        ISCED 5A, 6    0.04       NaN        ISCED 5A, 6    NaN
# 5       2.0  ISCED 3A, ISCED 4   -0.69       NaN  ISCED 3A, ISCED 4    NaN
#
#    HOMEPOS  HOMSCH  HOSTCUL  ICTATTNEG  ICTATTPOS  ICTHOME  ICTRES  ICTSCH  \
# 1    -2.61     NaN      NaN        NaN        NaN      NaN   -3.16     NaN
# 2     1.41     NaN      NaN        NaN        NaN      NaN    1.15     NaN
# 3     0.14     NaN      NaN        NaN        NaN      NaN   -0.40     NaN
# 4    -0.73     NaN      NaN        NaN        NaN      NaN   -0.40     NaN
# 5    -0.57     NaN      NaN        NaN        NaN      NaN    0.24     NaN
#
#     IMMIG  INFOCAR  INFOJOB1  INFOJOB2  INSTMOT  INTMAT ISCEDD         ISCEDL  \
# 1  Native      NaN       NaN       NaN     0.80    0.91      A  ISCED level 3
# 2  Native      NaN       NaN       NaN    -0.39    0.00      A  ISCED level 3
# 3  Native      NaN       NaN       NaN     1.59    1.23      A  ISCED level 2
# 4  Native      NaN       NaN       NaN      NaN     NaN      A  ISCED level 2
# 5  Native      NaN       NaN       NaN     1.59    0.30      A  ISCED level 2
#
#     ISCEDO  LANGCOMM      LANGN  LANGRPPD  LMINS  MATBEH  MATHEFF  MATINTFC  \
# 1  General       NaN  Albanian        NaN    NaN  0.6426    -0.77   -0.7332
# 2  General       NaN  Albanian        NaN  315.0  1.4702     0.34   -0.2514
# 3  General       NaN  Albanian        NaN  300.0  0.9618     0.34   -0.2514
# 4  General       NaN  Albanian        NaN  135.0     NaN      NaN       NaN
# 5  General       NaN  Albanian        NaN    NaN  1.8169     0.41    0.6584
#
#    MATWKETH             MISCED  MMINS   MTSUP  \
# 1    0.2882  ISCED 3A, ISCED 4    NaN -0.9508
# 2    0.6490        ISCED 5A, 6  270.0     NaN
# 3    2.0389        ISCED 5A, 6    NaN     NaN
# 4       NaN        ISCED 3B, C  135.0  1.6748
# 5    1.6881               None    NaN  0.6709
#
#                                         OCOD1  \
# 1                         Building architects
# 2  Tailors, dressmakers, furriers and hatters
# 3                                   Housewife
# 4                                   Housewife
# 5                                   Housewife
#
#                                                OCOD2  OPENPS  OUTHOURS  PARED  \
# 1                            Primary school teachers  0.0521       NaN   12.0
# 2                    Building construction labourers -0.9492       8.0   16.0
# 3                    Bricklayers and related workers  0.9383      24.0   16.0
# 4  Cleaners and helpers in offices, hotels and ot...     NaN      17.0   16.0
# 5                                         Economists  1.2387       NaN   12.0
#
#    PERSEV                    REPEAT  SCMAT  SMINS  STUDREL  SUBNORM  TCHBEHFA  \
# 1 -0.3407  Did not repeat a <grade>   0.41    NaN    -1.04  -0.0455    1.3625
# 2  1.3116  Did not repeat a <grade>    NaN   90.0      NaN   0.6602       NaN
# 3  0.9918  Did not repeat a <grade>    NaN    NaN      NaN   2.2350       NaN
# 4     NaN  Did not repeat a <grade>   0.18   90.0      NaN      NaN    0.7644
# 5  1.0819  Did not repeat a <grade>  -0.06    NaN    -0.02   2.8039    0.7644
#
#    TCHBEHSO  TCHBEHTD  TEACHSUP   TESTLANG  TIMEINT  USEMATH  USESCH  WEALTH  \
# 1    0.9374    0.4297      1.68  Albanian       NaN      NaN     NaN   -2.92
# 2       NaN       NaN       NaN  Albanian       NaN      NaN     NaN    0.69
# 3       NaN       NaN       NaN  Albanian       NaN      NaN     NaN   -0.23
# 4    3.3108    2.3916      1.68  Albanian       NaN      NaN     NaN   -1.17
# 5    0.9374    0.4297      0.11  Albanian       NaN      NaN     NaN   -1.17
#
#    ANCATSCHL  ANCATTLNACT  ANCBELONG  ANCCLSMAN  ANCCOGACT  ANCINSTMOT  \
# 1    -1.8636      -0.6779    -0.7351    -0.7808    -0.0219     -0.1562
# 2        NaN          NaN        NaN        NaN        NaN         NaN
# 3        NaN          NaN        NaN        NaN        NaN         NaN
# 4        NaN          NaN        NaN        NaN        NaN         NaN
# 5     0.6517       0.4908     0.8675     0.0505     0.4940      0.9986
#
# 5   12.7307    4.2436    4.2436    4.2436    4.2436   12.7307   12.7307
#
#    W_FSTR70  W_FSTR71  W_FSTR72  W_FSTR73  W_FSTR74  W_FSTR75  W_FSTR76  \
# 1    4.3389   13.0829   13.9235    4.3389    4.3313   13.7954   13.9235
# 2    4.3389   13.0829   13.9235    4.3389    4.3313   13.7954   13.9235
# 3    4.2436   12.7307   12.7307    4.2436    4.2436   12.7307   12.7307
# 4    4.2436   12.7307   12.7307    4.2436    4.2436   12.7307   12.7307
# 5    4.2436   12.7307   12.7307    4.2436    4.2436   12.7307   12.7307
#
#    W_FSTR77  W_FSTR78  W_FSTR79  W_FSTR80  WVARSTRR  VAR_UNIT  SENWGT_STU  \
# 1   13.1249   13.1249    4.3389   13.0829        19         1      0.2098
# 2   13.1249   13.1249    4.3389   13.0829        19         1      0.2098
# 3   12.7307   12.7307    4.2436   12.7307        19         1      0.1999
# 4   12.7307   12.7307    4.2436   12.7307        19         1      0.1999
# 5   12.7307   12.7307    4.2436   12.7307        19         1      0.1999
#
#    VER_STU
# 1  22NOV13
# 2  22NOV13
# 3  22NOV13
# 4  22NOV13
# 5  22NOV13

# %%
pisa.shape
# Out:
# (485490, 635)

# %% [markdown]
# ### What is the structure of your dataset?
#
# The data set contains 635 features and 485490 student survey results. So it's a very reach dataset which requires some work to understand the features (hopefully there's the dicitionnary) and then filter out the features of interest.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# I'm interested to know what feature impact the score of the student in math, reading and science.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# First I need the scores. Those are expressed via a set of plausible value for mathematic, reading and science: PV1MATH, PV1READ, PV1SCIE.
#
# I expect that the parental context has an influence on the scores. So I focus on:
# * the level of education of the parents (HISCED);
# * the presence of the parents at home (ST11Q01: Mother at Home, ST11Q02: Father at Home)
# * the work of the parents (ST15Q01: mother, ST19Q01: father)
# * the time that parent spend working with the student (ST57Q05)
#
# I wonder if cultural aspects can impact the scores and so I will consider the immigrant feature (IMMIG) to measure it.

# %%
pisa = pisa[['STIDSTD','ST04Q01','CNT','PV1MATH','PV1READ','PV1SCIE','ST11Q01','ST11Q02','ST57Q05','HISCED','IMMIG']]
pisa.rename({'STIDSTD':'StudentId', 'ST04Q01':'Gender','CNT':'Country', 
             'PV1MATH':'MathScore', 'PV1READ':"ReadingScore",'PV1SCIE':'ScienceScore',
             'ST11Q01':'MotherPresent', 'ST11Q02':'FatherPresent', 'ST57Q05':'StudyTimeWithParent',
             'HISCED':'ParentsHighestEducation', 'IMMIG':'ImmigrationStatus'
            }, 
            axis='columns', inplace=True)

# %%
pisa.head()
# Out:
#    StudentId  Gender  Country  MathScore  ReadingScore  ScienceScore  \
# 1          1  Female  Albania   406.8469      249.5762      341.7009
# 2          2  Female  Albania   486.1427      406.2936      548.9929
# 3          3  Female  Albania   533.2684      401.2100      499.6643
# 4          4  Female  Albania   412.2215      547.3630      438.6796
# 5          5  Female  Albania   381.9209      311.7707      361.5628
#
#   MotherPresent FatherPresent  StudyTimeWithParent ParentsHighestEducation  \
# 1           Yes           Yes                  NaN       ISCED 3A, ISCED 4
# 2           Yes           Yes                  0.0             ISCED 5A, 6
# 3           Yes           Yes                  2.0             ISCED 5A, 6
# 4           Yes           Yes                  0.0             ISCED 5A, 6
# 5           Yes           Yes                  NaN       ISCED 3A, ISCED 4
#
#   ImmigrationStatus
# 1            Native
# 2            Native
# 3            Native
# 4            Native
# 5            Native

# %%
pisa.dtypes
# Out:
# StudentId                    int64
# Gender                      object
# Country                     object
# MathScore                  float64
# ReadingScore               float64
# ScienceScore               float64
# MotherPresent               object
# FatherPresent               object
# StudyTimeWithParent        float64
# ParentsHighestEducation     object
# ImmigrationStatus           object
# dtype: object

# %% [markdown]
# ### Further Data Wrangling
# #### Data assessment

# %%
print(pisa.shape)
for col in pisa.columns: 
    print('{} contains {} null value'.format(col, pisa[col].isna().sum()))
# Out:
# (485490, 11)
# StudentId contains 0 null value
# Gender contains 0 null value
# Country contains 0 null value
# MathScore contains 0 null value
# ReadingScore contains 0 null value
# ScienceScore contains 0 null value
# MotherPresent contains 24931 null value
# FatherPresent contains 44454 null value
# StudyTimeWithParent contains 195988 null value
# ParentsHighestEducation contains 12399 null value
# ImmigrationStatus contains 13697 null value

# %%
pisa.describe()
# Out:
#            StudentId      MathScore   ReadingScore   ScienceScore  \
# count  485490.000000  485490.000000  485490.000000  485490.000000
# mean     6134.066201     469.621653     472.004640     475.769824
# std      6733.144944     103.265391     102.505523     101.464426
# min         1.000000      19.792800       0.083400       2.648300
# 25%      1811.000000     395.318600     403.600700     404.457300
# 50%      3740.000000     466.201900     475.455000     475.699400
# 75%      7456.000000     541.057800     544.502500     547.780700
# max     33806.000000     962.229300     904.802600     903.338300
#
#        StudyTimeWithParent
# count        289502.000000
# mean              1.213363
# std               2.353292
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               2.000000
# max              30.000000

# %%
print(pisa.Gender.unique())
print(pisa.MotherPresent.unique())
print(pisa.FatherPresent.unique())
print(pisa.ParentsHighestEducation.unique())
print(pisa.ImmigrationStatus.unique())
# Out:
# ['Female' 'Male']
# ['Yes' nan 'No']
# ['Yes' nan 'No']
# ['ISCED 3A, ISCED 4' 'ISCED 5A, 6' 'ISCED 3B, C' 'ISCED 2' 'ISCED 5B'
#  'None' 'ISCED 1' nan]
# ['Native' nan 'Second-Generation' 'First-Generation']

# %% [markdown]
# #### Fixing missing values
#
# To avoid any biased regarding the observations relative to parents, I prefer to drop the records containing null values. This will lead to a significant drop in the dataset however since I'm not interested by the representation of countries this does not matter.

# %%
pisa_clean = pisa.dropna(subset=['MotherPresent', 'FatherPresent', 'StudyTimeWithParent', 'ParentsHighestEducation', 'ImmigrationStatus'])
pisa_clean.shape
# Out:
# (258484, 11)

# %%
pisa_clean.head()
# Out:
#    StudentId  Gender  Country  MathScore  ReadingScore  ScienceScore  \
# 2          2  Female  Albania   486.1427      406.2936      548.9929
# 3          3  Female  Albania   533.2684      401.2100      499.6643
# 4          4  Female  Albania   412.2215      547.3630      438.6796
# 6          6  Female  Albania   396.3312      378.2544      384.3156
# 7          7  Female  Albania   438.0823      373.2503      508.1499
#
#   MotherPresent FatherPresent  StudyTimeWithParent ParentsHighestEducation  \
# 2           Yes           Yes                  0.0             ISCED 5A, 6
# 3           Yes           Yes                  2.0             ISCED 5A, 6
# 4           Yes           Yes                  0.0             ISCED 5A, 6
# 6           Yes           Yes                  1.0             ISCED 3B, C
# 7           Yes           Yes                  0.0             ISCED 5A, 6
#
#   ImmigrationStatus
# 2            Native
# 3            Native
# 4            Native
# 6            Native
# 7            Native

# %% [markdown]
# #### Collate 'parents presence' into a single column

# %%
pisa_clean['SingleParent'] = (pisa_clean.MotherPresent == 'No') | (pisa_clean.FatherPresent == 'No')

pisa_clean.head()
# Out:
# /Users/rguitter/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    StudentId  Gender  Country  MathScore  ReadingScore  ScienceScore  \
# 2          2  Female  Albania   486.1427      406.2936      548.9929
# 3          3  Female  Albania   533.2684      401.2100      499.6643
# 4          4  Female  Albania   412.2215      547.3630      438.6796
# 6          6  Female  Albania   396.3312      378.2544      384.3156
# 7          7  Female  Albania   438.0823      373.2503      508.1499
#
#   MotherPresent FatherPresent  StudyTimeWithParent ParentsHighestEducation  \
# 2           Yes           Yes                  0.0             ISCED 5A, 6
# 3           Yes           Yes                  2.0             ISCED 5A, 6
# 4           Yes           Yes                  0.0             ISCED 5A, 6
# 6           Yes           Yes                  1.0             ISCED 3B, C
# 7           Yes           Yes                  0.0             ISCED 5A, 6
#
#   ImmigrationStatus  SingleParent
# 2            Native         False
# 3            Native         False
# 4            Native         False
# 6            Native         False
# 7            Native         False

# %% [markdown]
# #### Calculate the 'overall score'

# %%
pisa_clean.assign(OverallScore=(pisa_clean.MathScore + pisa_clean.ReadingScore + pisa_clean.ScienceScore) / 3)
pisa_clean = pisa_clean.drop(['MathScore','ReadingScore','ScienceScore'], axis=1)
pisa_clean.head()
# Out:
#    StudentId  Gender  Country MotherPresent FatherPresent  \
# 2          2  Female  Albania           Yes           Yes
# 3          3  Female  Albania           Yes           Yes
# 4          4  Female  Albania           Yes           Yes
# 6          6  Female  Albania           Yes           Yes
# 7          7  Female  Albania           Yes           Yes
#
#    StudyTimeWithParent ParentsHighestEducation ImmigrationStatus
# 2                  0.0             ISCED 5A, 6            Native
# 3                  2.0             ISCED 5A, 6            Native
# 4                  0.0             ISCED 5A, 6            Native
# 6                  1.0             ISCED 3B, C            Native
# 7                  0.0             ISCED 5A, 6            Native

# %% [markdown]
# #### Fix type issues
#
# * StudyTimeWithParent is an int64
# * Gender, ParentsHighestEducation and ImmigrationStatus are categories

# %%
pisa_clean.loc[:,'StudyTimeWithParent'] = pisa_clean.StudyTimeWithParent.astype('int64')

gender_dtype = pd.api.types.CategoricalDtype(categories=['Female','Male'])
pisa_clean.loc[:,'Gender'] = pisa_clean.Gender.astype(gender_dtype)

parentHE_dtype = pd.api.types.CategoricalDtype(
                    categories=['None','ISCED 1','ISCED 2','ISCED 3B, C','ISCED 3A, ISCED 4','ISCED 5B','ISCED 5A, 6'],
                    ordered=True)
pisa_clean.loc[:,'ParentsHighestEducation'] = pisa_clean.ParentsHighestEducation.astype(parentHE_dtype)

immig_dtype = pd.api.types.CategoricalDtype(categories=['Native','Second-Generation','First-Generation'], ordered=True)
pisa_clean.loc[:,'ImmigrationStatus'] = pisa_clean.ImmigrationStatus.astype(immig_dtype)

pisa_clean.dtypes
# Out:
# StudentId                     int64
# Gender                     category
# Country                      object
# MotherPresent                object
# FatherPresent                object
# StudyTimeWithParent           int64
# ParentsHighestEducation    category
# ImmigrationStatus          category
# dtype: object

# %% [markdown]
# #### Check the data

# %%
print(pisa_clean.Gender.unique())
print(pisa_clean.MotherPresent.unique())
print(pisa_clean.FatherPresent.unique())
print(pisa_clean.SingleParent.unique())
print(pisa_clean.ParentsHighestEducation.unique())
print(pisa_clean.ImmigrationStatus.unique())
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]
# ['Yes' 'No']
# ['Yes' 'No']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-148-712c18d3443e> in <module>
#       2 print(pisa_clean.MotherPresent.unique())
#       3 print(pisa_clean.FatherPresent.unique())
# ----> 4 print(pisa_clean.SingleParent.unique())
#       5 print(pisa_clean.ParentsHighestEducation.unique())
#       6 print(pisa_clean.ImmigrationStatus.unique())
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'SingleParent'

# %%
# save to a file
pisa_clean.to_csv("pisa2012_clean.csv", index=False, encoding='latin-1')

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.

# %%
pisa.StudyTimeWithParent.hist()

# %% [markdown]
# > Make sure that, after every plot or related series of plots, that you
# include a Markdown cell with comments about what you observed, and what
# you plan on investigating next.

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > Your answer here!
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Your answer here!

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > Your answer here!
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!
